# %%
import pandas as pd
mdb = pd.read_csv("c:\\Users\\santi\\Downloads\\mongo_temp_hist.txt")
sql = pd.read_csv("c:\\Users\\santi\\Downloads\\Mysql_temp_hist.txt")
mdb['Database'] = "MongoDB"
sql['Database'] = "MySQL"
merged_df = pd.concat([sql, mdb])
merged_df.reset_index(inplace=True)
merged_df
# Out:
#     index                              metric                   submetric  \
# 0       0                           [OVERALL]                 RunTime(ms)
# 1       1                           [OVERALL]         Throughput(ops/sec)
# 2       2                    [TOTAL_GCS_Copy]                       Count
# 3       3                [TOTAL_GC_TIME_Copy]                    Time(ms)
# 4       4              [TOTAL_GC_TIME_%_Copy]                     Time(%)
# 5       5        [TOTAL_GCS_MarkSweepCompact]                       Count
# 6       6    [TOTAL_GC_TIME_MarkSweepCompact]                    Time(ms)
# 7       7  [TOTAL_GC_TIME_%_MarkSweepCompact]                     Time(%)
# 8       8                         [TOTAL_GCs]                       Count
# 9       9                     [TOTAL_GC_TIME]                    Time(ms)
# 10     10                   [TOTAL_GC_TIME_%]                     Time(%)
# 11     11                           [CLEANUP]                  Operations
# 12     12                           [CLEANUP]          AverageLatency(us)
# 13     13                           [CLEANUP]         LatencyVariance(us)
# 14     14                           [CLEANUP]              MinLatency(us)
# 15     15                           [CLEANUP]              MaxLatency(us)
# 16     16                           [CLEANUP]   95thPercentileLatency(us)
# 17     17                           [CLEANUP]   99thPercentileLatency(us)
# 18     18                            [INSERT]                  Operations
# 19     19                            [INSERT]          AverageLatency(us)
# 20     20                            [INSERT]         LatencyVariance(us)
# 21     21                            [INSERT]              MinLatency(us)
# 22     22                            [INSERT]              MaxLatency(us)
# 23     23                            [INSERT]   95thPercentileLatency(us)
# 24     24                            [INSERT]   99thPercentileLatency(us)
# 25     25                            [INSERT]                   Return=OK
# 26      0                           [OVERALL]                 RunTime(ms)
# 27      1                           [OVERALL]         Throughput(ops/sec)
# 28      2                    [TOTAL_GCS_Copy]                       Count
# 29      3                [TOTAL_GC_TIME_Copy]                    Time(ms)
# 30      4              [TOTAL_GC_TIME_%_Copy]                     Time(%)
# 31      5        [TOTAL_GCS_MarkSweepCompact]                       Count
# 32      6    [TOTAL_GC_TIME_MarkSweepCompact]                    Time(ms)
# 33      7  [TOTAL_GC_TIME_%_MarkSweepCompact]                     Time(%)
# 34      8                         [TOTAL_GCs]                       Count
# 35      9                     [TOTAL_GC_TIME]                    Time(ms)
# 36     10                   [TOTAL_GC_TIME_%]                     Time(%)
# 37     11                           [CLEANUP]                  Operations
# 38     12                           [CLEANUP]          AverageLatency(us)
# 39     13                           [CLEANUP]         LatencyVariance(us)
# 40     14                           [CLEANUP]              MinLatency(us)
# 41     15                           [CLEANUP]              MaxLatency(us)
# 42     16                           [CLEANUP]   95thPercentileLatency(us)
# 43     17                           [CLEANUP]   99thPercentileLatency(us)
# 44     18                            [INSERT]                  Operations
# 45     19                            [INSERT]          AverageLatency(us)
# 46     20                            [INSERT]         LatencyVariance(us)
# 47     21                            [INSERT]              MinLatency(us)
# 48     22                            [INSERT]              MaxLatency(us)
# 49     23                            [INSERT]   95thPercentileLatency(us)
# 50     24                            [INSERT]   99thPercentileLatency(us)
# 51     25                            [INSERT]                   Return=OK
#
#            score Database
# 0   9.966800e+04    MySQL
# 1   1.003331e+02    MySQL
# 2   1.100000e+01    MySQL
# 3   4.800000e+01    MySQL
# 4   4.815989e-02    MySQL
# 5   0.000000e+00    MySQL
# 6   0.000000e+00    MySQL
# 7   0.000000e+00    MySQL
# 8   1.100000e+01    MySQL
# 9   4.800000e+01    MySQL
# 10  4.815989e-02    MySQL
# 11  1.000000e+00    MySQL
# 12  1.506000e+03    MySQL
# 13  0.000000e+00    MySQL
# 14  1.506000e+03    MySQL
# 15  1.506000e+03    MySQL
# 16  1.000000e+03    MySQL
# 17  1.000000e+03    MySQL
# 18  1.000000e+04    MySQL
# 19  9.877662e+03    MySQL
# 20  2.123280e+07    MySQL
# 21  3.958000e+03    MySQL
# 22  9.916400e+04    MySQL
# 23  1.700000e+04    MySQL
# 24  2.300000e+04    MySQL
# 25  1.000000e+04    MySQL
# 26  2.641000e+03  MongoDB
# 27  3.786445e+03  MongoDB
# 28  9.000000e+00  MongoDB
# 29  6.300000e+01  MongoDB
# 30  2.385460e+00  MongoDB
# 31  0.000000e+00  MongoDB
# 32  0.000000e+00  MongoDB
# 33  0.000000e+00  MongoDB
# 34  9.000000e+00  MongoDB
# 35  6.300000e+01  MongoDB
# 36  2.385460e+00  MongoDB
# 37  1.000000e+00  MongoDB
# 38  1.654000e+03  MongoDB
# 39  0.000000e+00  MongoDB
# 40  1.654000e+03  MongoDB
# 41  1.654000e+03  MongoDB
# 42  1.000000e+03  MongoDB
# 43  1.000000e+03  MongoDB
# 44  1.000000e+04  MongoDB
# 45  1.821202e+02  MongoDB
# 46  3.470944e+06  MongoDB
# 47  5.100000e+01  MongoDB
# 48  1.725530e+05  MongoDB
# 49  0.000000e+00  MongoDB
# 50  2.000000e+03  MongoDB
# 51  1.000000e+04  MongoDB

# %%
plot = merged_df.iloc[[0,1,12,15,19,22,
                26,27,38,41,45,48]]
plot
# Out:
#     index     metric             submetric          score Database
# 0       0  [OVERALL]           RunTime(ms)   99668.000000    MySQL
# 1       1  [OVERALL]   Throughput(ops/sec)     100.333106    MySQL
# 12     12  [CLEANUP]    AverageLatency(us)    1506.000000    MySQL
# 15     15  [CLEANUP]        MaxLatency(us)    1506.000000    MySQL
# 19     19   [INSERT]    AverageLatency(us)    9877.662300    MySQL
# 22     22   [INSERT]        MaxLatency(us)   99164.000000    MySQL
# 26      0  [OVERALL]           RunTime(ms)    2641.000000  MongoDB
# 27      1  [OVERALL]   Throughput(ops/sec)    3786.444529  MongoDB
# 38     12  [CLEANUP]    AverageLatency(us)    1654.000000  MongoDB
# 41     15  [CLEANUP]        MaxLatency(us)    1654.000000  MongoDB
# 45     19   [INSERT]    AverageLatency(us)     182.120200  MongoDB
# 48     22   [INSERT]        MaxLatency(us)  172553.000000  MongoDB

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 8))

# overall
a = plot[plot['metric']=="[OVERALL]"]
a['metric'] ='Insert'
sns.barplot(x=a['submetric'],y=a['score'],hue=a['Database'], ax=ax1)
ax1.set_title('Overall',fontsize=20)

# Insert
a = plot[plot['metric']=="[INSERT]"]
a['metric'] ='Overall'
sns.barplot(x=a['submetric'],y=a['score'],hue=a['Database'], ax=ax2)
ax2.set_title('Insert',fontsize=20)

#cleanup
a = plot[plot['metric']=="[CLEANUP]"]
a['metric'] ='Cleanup'
sns.barplot(x=a['submetric'],y=a['score'],hue=a['Database'], ax=ax3)
ax3.set_title('Cleanup',fontsize=20)

fig.suptitle('Read-heavy performances',fontsize=25)

plt.show()
# Out:
# C:\Users\santi\AppData\Local\Temp\ipykernel_14688\4041164061.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['metric'] ='Insert'
# C:\Users\santi\AppData\Local\Temp\ipykernel_14688\4041164061.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['metric'] ='Overall'
# C:\Users\santi\AppData\Local\Temp\ipykernel_14688\4041164061.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['metric'] ='Cleanup'

# %%
insert = pd.read_csv('c:\\Users\\santi\\Downloads\\insert\\all together.txt')
insert
# Out:
#    Load                metric          score       db
# 0    5k           RunTime(ms)    1834.000000  MongoDB
# 1    5k   Throughput(ops/sec)    2726.281352  MongoDB
# 2   10k           RunTime(ms)    2402.000000  MongoDB
# 3   10k   Throughput(ops/sec)    4163.197336  MongoDB
# 4   50k           RunTime(ms)   10242.000000  MongoDB
# 5   50k   Throughput(ops/sec)    4881.859012  MongoDB
# 6    5k           RunTime(ms)   34794.000000    Mysql
# 7    5k   Throughput(ops/sec)     143.702937    Mysql
# 8   10k           RunTime(ms)  102005.000000    Mysql
# 9   10k   Throughput(ops/sec)      98.034410    Mysql
# 10  50k           RunTime(ms)  682003.000000    Mysql
# 11  50k   Throughput(ops/sec)      73.313460    Mysql

# %%
insert['metric'].unique()
# Out:
# array([' RunTime(ms)', ' Throughput(ops/sec)'], dtype=object)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

#runtime
a = insert[insert['metric']==' RunTime(ms)']
sns.lineplot(x=a['Load'], y=a['score'],hue=a['db'],palette="husl",ax=ax1,marker='o', markersize=15)
ax1.set_xlabel("Load")
ax1.set_ylabel("RunTime(ms)")
ax1.set_title("Runtime")

#Throughput(ops/sec)
a = insert[insert['metric']==' Throughput(ops/sec)']
sns.lineplot(x=a['Load'], y=a['score'],hue=a['db'],palette="husl",ax=ax2,marker='o', markersize=15)
ax2.set_xlabel("Load")
ax2.set_ylabel("Throughput(ops/sec)")
ax2.set_title("Throughput")

fig.suptitle("Insert heavy scalability",fontsize=20)
# Out:
# Text(0.5, 0.98, 'Insert heavy scalability')
